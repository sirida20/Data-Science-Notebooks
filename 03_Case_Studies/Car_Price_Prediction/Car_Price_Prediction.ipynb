# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/sirida20/Data-Science-Notebooks/blob/main/03_Case_Studies/Car_Price_Prediction/Car_Price_Prediction.ipynb)

# %% [markdown]
# Importing the Dependecies

# %%
#Workflow Of Sci-Kit Learn
'''
1) Setting up the data
2) Creating the Model
3) Training the Model
4) Prediction
'''

# %%
#Importing important libraries
import numpy as np
import pandas as pd

# %%
#Importing LinearRegression Model
from sklearn.linear_model import LinearRegression

# %%
#Importing accuracy score function
from sklearn import metrics

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# Data Collection and Analysis

# %%
car_dataset = pd.read_csv('car data.csv')

# %%
#Displaying first 5 rows
car_dataset.head()

# %%
#Finding no. of rows and columns
car_dataset.shape

# %%
#Info of the dataset
car_dataset.info()

# %%
#Finding the sum of null values
car_dataset.isnull().sum()

# %%
#Checking the distribution of categorical data
#car_dataset['Fuel_Type'].unique()
pd.unique(car_dataset['Fuel_Type'])
car_dataset['Fuel_Type'].value_counts()

# %%
#Transmission
pd.unique(car_dataset['Transmission'])
car_dataset['Transmission'].value_counts()

# %%
#Seller Type
pd.unique(car_dataset['Seller_Type'])
car_dataset['Seller_Type'].value_counts()

# %% [markdown]
# Encoding the Categorical Data

# %%
#Encoding the Fuel_Type column
car_dataset.replace({'Fuel_Type':{'Petrol':0, 'Diesel':1, 'CNG':2}}, inplace = True)
#Petrol - 0
#Diesel - 1
#CNG - 2

#Encoding the Transmission Column
car_dataset.replace({'Transmission':{'Manual':0, 'Automatic':1}}, inplace = True)
#Manual - 0
#Automatic - 1

#Encoding the Seller_Type Column
car_dataset.replace({'Seller_Type':{'Dealer':0, 'Individual':1}}, inplace = True)
#Dealer - 0
#Individual - 1

# %%
car_dataset

# %% [markdown]
# Splitting the data into Training Data and Testing Data

# %%
X = car_dataset.drop(['Car_Name', 'Selling_Price'], axis = 1)
Y = car_dataset['Selling_Price']

# %%
#Splitting the data into training data and testing data
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state = 2)

# %%
print(X.shape, X_train.shape, Y_test.shape)

# %% [markdown]
# Model Training

# %%
#Calling Linear Regression Model
model = LinearRegression()

# %%
#Training the ML Model using training data
model.fit(X_train, Y_train)

# %%
training_data_prediction = model.predict(X_train)

# %%
'''
training_data_accuracy = accuracy_score(Y_train, X_train_prediction)
print("Accuracy Score of training data", training_data_accuracy)
'''
training_data_accuracy = metrics.r2_score(Y_train, training_data_prediction)
print("Accuracy Score of training data", training_data_accuracy)

# %%
testing_data_prediction = model.predict(X_test)

# %%
testing_data_accuracy = metrics.r2_score(Y_test, testing_data_prediction)
print("Accuracy Score of training data", testing_data_accuracy)

# %% [markdown]
# Building a Predictive System

# %%
input_data = (2010,7.98,41442,0,0,0,0)

input_data_as_numpy_array = np.array(input_data)
#Reshape the numpy array as we are predicting for one data point
input_data_reshape = input_data_as_numpy_array.reshape(1,-1)

# %%
prediction = model.predict(input_data_reshape)
print('Car price according to the prediction:', prediction)
